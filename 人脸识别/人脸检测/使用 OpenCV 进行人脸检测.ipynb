# %% [markdown]
# # 使用 OpenCV 进行人脸检测

# %%
#The line below is necesary to show Matplotlib's plots inside a Jupyter Notebook 
# 表示我们的在notebook要使用matplotlib进行一个图片的渲染
# %matplotlib inline

import cv2
from matplotlib import pyplot as plt

# 图片文件所在位置
imagePath = './face_detection/test_face_detection.jpg'
cascPath = "./face_detection/haarcascade_frontalface_default.xml"

# Create the haar cascade
faceCascade = cv2.CascadeClassifier(cascPath)

# Read the image
image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect faces in the image
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
    #flags = cv2.CV_HAAR_SCALE_IMAGE
)

print("Found {0} faces!".format(len(faces)))

# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

plt.title("Faces found")
# 取消坐标轴
plt.axis("off")
# 我们的plt默认是使用BGR画图，这里将BGR转为RGB
# plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.imshow(image)
plt.show()
# Out:
# Found 4 faces!

# %% [markdown]
# # 使用 face_recognition 库进行人脸检测

# %%
import face_recognition

imagePath = './face_detection/test_face_detection.jpg'

# Load the image with face_recognition
image = face_recognition.load_image_file(imagePath)
# Detect faces in the image
face_locations = face_recognition.face_locations(image)

print("Found {0} faces!".format(len(face_locations)))


# Read the image with openCV
image = cv2.imread(imagePath)

# Draw a rectangle around the faces
for (top, right, bottom, left) in face_locations:
    cv2. (image, (left, top), (right, bottom), (0, 255, 0), 2)


plt.title("Faces found")
plt.axis("off")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# Found 5 faces!
